# %% [markdown]
# # VAR, VARMA and VARMAX
# Author: Geovanna Santos Nobre de Oliveira

# %% [markdown]
# ## VAR

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from tqdm import tqdm_notebook
from itertools import product

import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %% [markdown]
# ### United States Macroeconomic Dataset

# %%
macro_data = sm.datasets.macrodata.load_pandas()
macro_data = macro_data.data
macro_data.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, dpi=240)

ax1.plot(macro_data['realgdp'], color='black', linewidth=1)
ax1.set_title('realgdp')
ax1.xaxis.set_ticks_position('none')
ax1.yaxis.set_ticks_position('none')
ax1.spines['top'].set_alpha(0)
ax1.tick_params(labelsize=6)

ax2.plot(macro_data['realcons'], color='black', linewidth=1)
ax2.set_title('realcons')
ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')
ax2.spines['top'].set_alpha(0)
ax2.tick_params(labelsize=6)

# %%
ad_fuller_result_1 = adfuller(macro_data['realgdp'].diff()[1:])

print('realgdp')
print(f'ADF Statistica: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n----------------------------------\n')

ad_fuller_result_2 = adfuller(macro_data['realcons'].diff()[1:])

print('realcons')
print(f'ADF Statistica: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')
# Out:
# realgdp
# ADF Statistica: -6.305695561658105
# p-value: 3.327882187668224e-08
#
# ----------------------------------
#
# realcons
# ADF Statistica: -4.204306080845245
# p-value: 0.0006479282158627595

# %%
def optimize_VAR(endog):
    """
        Retorna um dataframe com parâmetros e seu correspondente MSE

    Args:
        endog: time series
    """

    results = []

    for i in tqdm_notebook(range(15)):
        try:
            model = VARMAX(endog, order=(i, 0)).fit(disp=False)
        except:
            continue

        mse = model.mse
        results.append([i, mse])

    result_df = pd.DataFrame(results)
    result_df.columns = ['p', 'mse']

    result_df = result_df.sort_values(
        by='mse', ascending=True).reset_index(drop=True)

    return result_df

# %%
endog = macro_data[['realgdp', 'realcons']]

result_df = optimize_VAR(endog)
result_df
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#      p           mse
# 0   11  1.442852e+05
# 1   12  1.482786e+05
# 2   13  1.530864e+05
# 3    8  1.588906e+05
# 4    7  1.635689e+05
# 5   10  1.636941e+05
# 6    9  1.662454e+05
# 7    6  1.695968e+05
# 8    5  1.812595e+05
# 9    3  1.880532e+05
# 10   4  2.040612e+05
# 11  14  2.468477e+06
# 12   2  9.973194e+06
# 13   1  8.663151e+07

# %%
best_model = VARMAX(endog, order=(11, 0))
res = best_model.fit(disp=False)
print(res.summary())
# Out:
#                               Statespace Model Results
# ===================================================================================
# Dep. Variable:     ['realgdp', 'realcons']   No. Observations:                  203
# Model:                             VAR(11)   Log Likelihood               -1985.764
#                                + intercept   AIC                           4069.528
# Date:                     Sat, 24 Sep 2022   BIC                           4231.875
# Time:                             20:17:28   HQIC                          4135.207
# Sample:                                  0
#                                      - 203
# Covariance Type:                       opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.01, 0.08   Jarque-Bera (JB):           4.42, 9.05
# Prob(Q):                        0.94, 0.77   Prob(JB):                   0.11, 0.01
# Heteroskedasticity (H):         1.88, 2.48   Skew:                       0.33, 0.16
# Prob(H) (two-sided):            0.01, 0.00   Kurtosis:                   3.28, 3.98
#                           Results for equation realgdp
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept       36.5282     21.950      1.664      0.096      -6.493      79.550
# L1.realgdp       0.8652      0.114      7.581      0.000       0.642       1.089
# L1.realcons      0.9402      0.198      4.760      0.000       0.553       1.327
# L2.realgdp       0.0453      0.149      0.305      0.761      -0.246       0.337
# L2.realcons     -0.1751      0.267     -0.657      0.511      -0.698       0.347
# L3.realgdp      -0.0934      0.136     -0.687      0.492      -0.360       0.173
# L3.realcons     -0.3904      0.270     -1.448      0.148      -0.919       0.138
# L4.realgdp       0.2368      0.150      1.582      0.114      -0.057       0.530
# L4.realcons     -0.4067      0.302     -1.349      0.177      -0.998       0.184
# L5.realgdp      -0.1469      0.160     -0.915      0.360      -0.461       0.168
# L5.realcons      0.0246      0.322      0.076      0.939      -0.606       0.655
# L6.realgdp       0.0275      0.182      0.151      0.880      -0.329       0.384
# L6.realcons      0.2344      0.289      0.811      0.417      -0.332       0.801
# L7.realgdp      -0.0105      0.185     -0.057      0.955      -0.372       0.351
# L7.realcons     -0.1325      0.256     -0.518      0.605      -0.634       0.369
# L8.realgdp       0.0194      0.183      0.106      0.915      -0.339       0.378
# L8.realcons     -0.2050      0.354     -0.580      0.562      -0.898       0.488
# L9.realgdp       0.2775      0.181      1.535      0.125      -0.077       0.632
# L9.realcons     -0.1178      0.391     -0.302      0.763      -0.883       0.648
# L10.realgdp     -0.1526      0.175     -0.873      0.383      -0.495       0.190
# L10.realcons     0.0450      0.317      0.142      0.887      -0.577       0.667
# L11.realgdp     -0.1303      0.109     -1.193      0.233      -0.344       0.084
# L11.realcons     0.2677      0.259      1.035      0.301      -0.239       0.775
#                          Results for equation realcons
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept       -3.4143     15.260     -0.224      0.823     -33.324      26.495
# L1.realgdp      -0.0468      0.067     -0.693      0.488      -0.179       0.085
# L1.realcons      1.3235      0.103     12.858      0.000       1.122       1.525
# L2.realgdp      -0.0400      0.103     -0.390      0.697      -0.241       0.161
# L2.realcons      0.0502      0.151      0.333      0.739      -0.245       0.345
# L3.realgdp      -0.0182      0.095     -0.191      0.848      -0.205       0.169
# L3.realcons      0.0374      0.165      0.227      0.821      -0.286       0.361
# L4.realgdp       0.0982      0.084      1.166      0.244      -0.067       0.263
# L4.realcons     -0.4532      0.168     -2.690      0.007      -0.783      -0.123
# L5.realgdp       0.0229      0.090      0.254      0.799      -0.154       0.200
# L5.realcons      0.0906      0.196      0.461      0.645      -0.294       0.475
# L6.realgdp      -0.0047      0.102     -0.047      0.963      -0.204       0.194
# L6.realcons      0.0289      0.154      0.188      0.851      -0.272       0.330
# L7.realgdp      -0.0938      0.092     -1.024      0.306      -0.273       0.086
# L7.realcons      0.0206      0.188      0.110      0.913      -0.348       0.389
# L8.realgdp       0.1423      0.092      1.546      0.122      -0.038       0.323
# L8.realcons     -0.1921      0.197     -0.976      0.329      -0.578       0.194
# L9.realgdp       0.0494      0.086      0.572      0.567      -0.120       0.219
# L9.realcons      0.0299      0.208      0.144      0.886      -0.377       0.437
# L10.realgdp     -0.1297      0.085     -1.527      0.127      -0.296       0.037
# L10.realcons     0.0534      0.183      0.292      0.770      -0.305       0.411
# L11.realgdp      0.0392      0.067      0.587      0.557      -0.092       0.170
# L11.realcons    -0.0162      0.149     -0.109      0.913      -0.309       0.276
#                                    Error covariance matrix
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# sqrt.var.realgdp             46.4553      2.990     15.539      0.000      40.596      52.315
# sqrt.cov.realgdp.realcons    15.7598      2.142      7.359      0.000      11.562      19.957
# sqrt.var.realcons            22.7858      1.469     15.511      0.000      19.907      25.665
# =============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res.plot_diagnostics()

# %%
n_forecast = 3
predict = res.get_prediction(end=best_model.nobs + n_forecast)
idx = np.arange(len(predict.predicted_mean))

predict.predicted_mean.tail(3)
# Out:
#           realgdp     realcons
# 204  13160.375262  9293.310768
# 205  13187.998799  9295.260465
# 206  13227.920040  9296.615411

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, dpi=240)

ax1.plot(macro_data['realgdp'], color='black', linewidth=1)
ax1.plot(idx[-n_forecast:], 
         predict.predicted_mean['realgdp'][-n_forecast:], 
         color='blue',
         ls='--',
         linewidth=1
         )
ax1.set_title('realgdp')
ax1.xaxis.set_ticks_position('none')
ax1.yaxis.set_ticks_position('none')
ax1.spines['top'].set_alpha(0)
ax1.tick_params(labelsize=6)

ax2.plot(macro_data['realcons'], color='black', linewidth=1)
ax2.plot(idx[-n_forecast:], 
         predict.predicted_mean['realcons'][-n_forecast:], 
         color='blue',
         ls='--',
         linewidth=1
         )
ax2.set_title('realgdp')
ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')
ax2.spines['top'].set_alpha(0)
ax2.tick_params(labelsize=6)

plt.tight_layout()

# %%
print('realcons causa realgdp?\n')
print('--------------------------------')
granger_1 = grangercausalitytests(macro_data[['realgdp', 'realcons']].diff()[1:], [12])

print('\nrealgdp causa realcons?\n')
print('--------------------------------')
granger_2 = grangercausalitytests(macro_data[['realcons', 'realgdp']].diff()[1:], [12])
# Out:
# realcons causa realgdp?
#
# --------------------------------
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=6.1144  , p=0.0000  , df_denom=165, df_num=12
# ssr based chi2 test:   chi2=84.4900 , p=0.0000  , df=12
# likelihood ratio test: chi2=69.8992 , p=0.0000  , df=12
# parameter F test:         F=6.1144  , p=0.0000  , df_denom=165, df_num=12
#
# realgdp causa realcons?
#
# --------------------------------
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.1147  , p=0.0185  , df_denom=165, df_num=12
# ssr based chi2 test:   chi2=29.2218 , p=0.0037  , df=12
# likelihood ratio test: chi2=27.1813 , p=0.0073  , df=12
# parameter F test:         F=2.1147  , p=0.0185  , df_denom=165, df_num=12

# %% [markdown]
# ## VARMA

# %%
def optimize_VARMA(endog, parameters_list):
    """
        Retorma um dataframe com os parametros (p, q) e o MSE correspondente

    Args:
        endog: target
        parameters_list: lista de tuplas (p, q)
    """
    
    results = []
    
    for param in tqdm_notebook(parameters_list):
        try:
            model= VARMAX(endog, order=param).fit(disp=False)
        except:
            continue
        
        mse = model.mse 
        results.append([param, mse])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p, q)', 'mse']
    
    result_df = result_df.sort_values(by='mse', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
endog = macro_data[['realgdp', 'realcons']]

p = range(0, 4, 1)
q = range(0, 4, 1)

parameters = product(p,q)
parameters_list = list(parameters)

result_df_VARMA = optimize_VARMA(endog, parameters_list)
result_df_VARMA
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#     (p, q)           mse
# 0   (3, 3)  1.607716e+05
# 1   (3, 2)  1.643546e+05
# 2   (3, 1)  1.684850e+05
# 3   (3, 0)  1.880532e+05
# 4   (1, 1)  1.915088e+05
# 5   (2, 1)  4.553035e+05
# 6   (0, 1)  5.717763e+05
# 7   (1, 2)  7.190591e+05
# 8   (0, 3)  9.236038e+05
# 9   (1, 3)  1.157557e+06
# 10  (2, 2)  1.312809e+06
# 11  (2, 3)  1.873346e+06
# 12  (0, 2)  4.391539e+06
# 13  (2, 0)  9.973194e+06
# 14  (1, 0)  8.663151e+07

# %%
best_model_VARMA = VARMAX(endog, order=(3,3))

res_VARMA = best_model_VARMA.fit(disp=False)
print(res_VARMA.summary())
# Out:
#                               Statespace Model Results
# ===================================================================================
# Dep. Variable:     ['realgdp', 'realcons']   No. Observations:                  203
# Model:                          VARMA(3,3)   Log Likelihood               -1998.722
#                                + intercept   AIC                           4055.445
# Date:                     Sat, 24 Sep 2022   BIC                           4151.528
# Time:                             23:02:11   HQIC                          4094.316
# Sample:                                  0
#                                      - 203
# Covariance Type:                       opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.00, 0.04   Jarque-Bera (JB):           4.96, 4.80
# Prob(Q):                        0.98, 0.84   Prob(JB):                   0.08, 0.09
# Heteroskedasticity (H):         2.30, 2.75   Skew:                       0.27, 0.10
# Prob(H) (two-sided):            0.00, 0.00   Kurtosis:                   3.55, 3.73
#                            Results for equation realgdp
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# intercept         33.2024     58.991      0.563      0.574     -82.419     148.823
# L1.realgdp         0.5832      0.973      0.599      0.549      -1.324       2.490
# L1.realcons        1.1175      1.243      0.899      0.369      -1.319       3.554
# L2.realgdp         0.2769      0.951      0.291      0.771      -1.588       2.142
# L2.realcons        0.0378      0.888      0.043      0.966      -1.703       1.778
# L3.realgdp         0.0881      0.403      0.218      0.827      -0.702       0.879
# L3.realcons       -1.0864      0.836     -1.299      0.194      -2.726       0.553
# L1.e(realgdp)      0.2699      0.974      0.277      0.782      -1.639       2.179
# L1.e(realcons)    -0.1211      1.246     -0.097      0.923      -2.564       2.322
# L2.e(realgdp)      0.0213      0.488      0.044      0.965      -0.934       0.977
# L2.e(realcons)    -0.2024      0.677     -0.299      0.765      -1.530       1.125
# L3.e(realgdp)     -0.1327      0.117     -1.131      0.258      -0.363       0.097
# L3.e(realcons)     0.4223      0.410      1.030      0.303      -0.382       1.226
#                           Results for equation realcons
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# intercept         -7.2667     35.732     -0.203      0.839     -77.300      62.767
# L1.realgdp        -0.0100      0.816     -0.012      0.990      -1.609       1.589
# L1.realcons        1.5079      0.864      1.746      0.081      -0.185       3.201
# L2.realgdp        -0.2973      0.887     -0.335      0.737      -2.035       1.440
# L2.realcons        0.2981      0.753      0.396      0.692      -1.177       1.773
# L3.realgdp         0.3272      0.244      1.342      0.180      -0.151       0.805
# L3.realcons       -0.8338      0.623     -1.338      0.181      -2.056       0.388
# L1.e(realgdp)     -0.0359      0.827     -0.043      0.965      -1.657       1.585
# L1.e(realcons)    -0.2036      0.851     -0.239      0.811      -1.871       1.464
# L2.e(realgdp)      0.2709      0.322      0.842      0.400      -0.359       0.901
# L2.e(realcons)    -0.6258      0.449     -1.394      0.163      -1.506       0.254
# L3.e(realgdp)     -0.1153      0.097     -1.188      0.235      -0.305       0.075
# L3.e(realcons)     0.3967      0.255      1.556      0.120      -0.103       0.896
#                                    Error covariance matrix
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# sqrt.var.realgdp             47.1687      2.574     18.324      0.000      42.123      52.214
# sqrt.cov.realgdp.realcons    15.8825      2.208      7.192      0.000      11.554      20.211
# sqrt.var.realcons            25.4280      1.711     14.865      0.000      22.075      28.781
# =============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res_VARMA.plot_diagnostics();

# %%
n_forecast = 3

predict = res_VARMA.get_prediction(end = best_model_VARMA.nobs + n_forecast)
idx = np.arange(len(predict.predicted_mean))

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, dpi=240)

ax1.plot(macro_data['realgdp'], color='black', linewidth=1)
ax1.plot(idx[-n_forecast:], 
         predict.predicted_mean['realgdp'][-n_forecast:], 
         color='blue',
         ls='--',
         linewidth=1
         )
ax1.set_title('realgdp')
ax1.xaxis.set_ticks_position('none')
ax1.yaxis.set_ticks_position('none')
ax1.set_xlim(150,206)
ax1.spines['top'].set_alpha(0)
ax1.tick_params(labelsize=6)

ax2.plot(macro_data['realcons'], color='black', linewidth=1)
ax2.plot(idx[-n_forecast:], 
         predict.predicted_mean['realcons'][-n_forecast:], 
         color='blue',
         ls='--',
         linewidth=1
         )
ax2.set_title('realgdp')
ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')
ax2.set_xlim(150,206)
ax2.spines['top'].set_alpha(0)
ax2.tick_params(labelsize=6)

plt.tight_layout()

# %% [markdown]
# ## VARMAX

# %%
def optimize_VARMAX(endog, exog, parameters):
    """
        Retorna um dataframe com as duplas (p,q) e o MSE correspondente

    Args:
        endog: variaveis observadas - target
        exog: variáveis exógenas
        parameters: lista de tuplas (p, q)
    """
    
    results = []
    
    for param in tqdm_notebook(parameters_list):
        try:
            model = VARMAX(endog, exog, order=param).fit(disp=False)
        except:
            continue
        
        mse = model.mse
        results.append([param, mse])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p, q)', 'mse']
    
    result_df = result_df.sort_values(by='mse', ascending = True).reset_index(drop=True)
    
    return result_df

# %%
endog = macro_data[['realgdp', 'realcons']][:200]

exog_cols = macro_data.columns.drop(['year', 'quarter', 'realgdp', 'realcons'])
exog = macro_data[exog_cols][:200]

p = range(0, 4, 1)
q = range(0, 4, 1)

parameters = product(p,q)
parameters_list = list(parameters)

result_df_VARMAX = optimize_VARMAX(endog, exog, parameters_list)
result_df_VARMAX
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#     (p, q)          mse
# 0   (1, 3)  2317.210635
# 1   (3, 3)  2322.372006
# 2   (2, 3)  2343.218071
# 3   (3, 2)  2365.061400
# 4   (2, 2)  2397.324899
# 5   (1, 2)  2431.296836
# 6   (3, 1)  2465.096454
# 7   (3, 0)  2519.682401
# 8   (2, 1)  2539.431472
# 9   (1, 0)  2559.287041
# 10  (1, 1)  2575.697169
# 11  (2, 0)  2762.325825
# 12  (0, 3)  3994.369022
# 13  (0, 2)  4090.605521
# 14  (0, 1)  4700.775920

# %%
best_model_VARMAX = VARMAX(endog, exog, order=(1,3))

res_VARMAX = best_model_VARMAX.fit(disp=False)
print(res_VARMAX.summary())
# Out:
#                               Statespace Model Results
# ===================================================================================
# Dep. Variable:     ['realgdp', 'realcons']   No. Observations:                  200
# Model:                         VARMAX(1,3)   Log Likelihood               -1949.917
#                                + intercept   AIC                           3981.835
# Date:                     Sat, 24 Sep 2022   BIC                           4117.066
# Time:                             23:45:29   HQIC                          4036.561
# Sample:                                  0
#                                      - 200
# Covariance Type:                       opg
# ===================================================================================
# Ljung-Box (L1) (Q):             3.11, 0.20   Jarque-Bera (JB):           7.00, 2.86
# Prob(Q):                        0.08, 0.66   Prob(JB):                   0.03, 0.24
# Heteroskedasticity (H):         1.59, 2.50   Skew:                       0.16, 0.08
# Prob(H) (two-sided):            0.06, 0.00   Kurtosis:                   3.86, 3.56
#                            Results for equation realgdp
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# intercept       -188.0695    639.657     -0.294      0.769   -1441.774    1065.635
# L1.realgdp         0.6771      0.198      3.414      0.001       0.288       1.066
# L1.realcons       -0.1591      0.236     -0.675      0.500      -0.621       0.303
# L1.e(realgdp)      0.0229      0.269      0.085      0.932      -0.504       0.550
# L1.e(realcons)     0.0904      0.387      0.233      0.815      -0.669       0.850
# L2.e(realgdp)      0.1897      0.170      1.117      0.264      -0.143       0.523
# L2.e(realcons)     0.2004      0.247      0.813      0.416      -0.283       0.684
# L3.e(realgdp)     -0.0854      0.151     -0.566      0.571      -0.381       0.210
# L3.e(realcons)     0.1226      0.204      0.601      0.548      -0.277       0.522
# beta.realinv       0.3723      0.117      3.174      0.002       0.142       0.602
# beta.realgovt      0.0836      0.155      0.540      0.589      -0.220       0.387
# beta.realdpi       0.3713      0.096      3.860      0.000       0.183       0.560
# beta.cpi           2.2843      1.832      1.247      0.213      -1.307       5.875
# beta.m1            0.0392      0.184      0.213      0.831      -0.322       0.400
# beta.tbilrate     -5.8594    987.077     -0.006      0.995   -1940.495    1928.777
# beta.unemp       -25.1744     14.861     -1.694      0.090     -54.301       3.953
# beta.pop           3.4257      5.057      0.677      0.498      -6.486      13.337
# beta.infl          1.5042    987.280      0.002      0.999   -1933.529    1936.538
# beta.realint      -1.3328    986.848     -0.001      0.999   -1935.520    1932.855
#                           Results for equation realcons
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# intercept        769.5044    587.619      1.310      0.190    -382.209    1921.217
# L1.realgdp         0.0807      0.175      0.462      0.644      -0.262       0.423
# L1.realcons        0.4882      0.212      2.307      0.021       0.073       0.903
# L1.e(realgdp)     -0.0950      0.240     -0.396      0.692      -0.565       0.375
# L1.e(realcons)    -0.0899      0.372     -0.242      0.809      -0.819       0.639
# L2.e(realgdp)      0.0255      0.188      0.135      0.892      -0.344       0.395
# L2.e(realcons)     0.2153      0.276      0.780      0.435      -0.325       0.756
# L3.e(realgdp)     -0.1826      0.169     -1.079      0.280      -0.514       0.149
# L3.e(realcons)     0.2329      0.233      0.999      0.318      -0.224       0.690
# beta.realinv       0.1564      0.098      1.600      0.110      -0.035       0.348
# beta.realgovt     -0.0225      0.132     -0.170      0.865      -0.282       0.237
# beta.realdpi       0.3932      0.092      4.294      0.000       0.214       0.573
# beta.cpi           0.5620      1.483      0.379      0.705      -2.345       3.469
# beta.m1            0.0497      0.152      0.327      0.744      -0.248       0.348
# beta.tbilrate    -12.4624   1024.404     -0.012      0.990   -2020.258    1995.333
# beta.unemp        -7.2903     12.213     -0.597      0.551     -31.227      16.647
# beta.pop          -4.6210      4.511     -1.024      0.306     -13.462       4.220
# beta.infl          6.9398   1024.486      0.007      0.995   -2001.016    2014.896
# beta.realint       4.7017   1024.522      0.005      0.996   -2003.324    2012.728
#                                    Error covariance matrix
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# sqrt.var.realgdp             46.0742      4.551     10.124      0.000      37.155      54.994
# sqrt.cov.realgdp.realcons    36.7480      4.969      7.395      0.000      27.008      46.488
# sqrt.var.realcons            27.4525      2.496     11.000      0.000      22.561      32.344
# =============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.13e+14. Standard errors may be unstable.

# %%
res_VARMAX.plot_diagnostics();

# %%
n_forecast = 3

predict = res_VARMAX.get_prediction(
    end = best_model_VARMAX.nobs + n_forecast, 
    exog = exog.iloc[-4:])

idx = np.arange(len(predict.predicted_mean))

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, dpi=240)

ax1.plot(macro_data['realgdp'][:200], color='black', linewidth=1)
ax1.plot(macro_data['realgdp'][200:], color='red', linewidth=1)
ax1.plot(idx[-n_forecast:], 
         predict.predicted_mean['realgdp'][-n_forecast:], 
         color='blue',
         ls='--',
         linewidth=1
         )
ax1.set_title('realgdp')
ax1.xaxis.set_ticks_position('none')
ax1.yaxis.set_ticks_position('none')
ax1.set_xlim(150,206)
ax1.spines['top'].set_alpha(0)
ax1.tick_params(labelsize=6)

ax2.plot(macro_data['realcons'][:200], color='black', linewidth=1)
ax2.plot(macro_data['realcons'][200:], color='red', linewidth=1)
ax2.plot(idx[-n_forecast:], 
         predict.predicted_mean['realcons'][-n_forecast:], 
         color='blue',
         ls='--',
         linewidth=1
         )
ax2.set_title('realgdp')
ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')
ax2.set_xlim(150,206)
ax2.spines['top'].set_alpha(0)
ax2.tick_params(labelsize=6)

plt.tight_layout()
